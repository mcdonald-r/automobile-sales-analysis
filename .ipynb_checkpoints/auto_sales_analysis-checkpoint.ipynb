# %% [markdown]
# # Automobile Sales Pipeline Risk Analysis
#
# ## Business Question
# Where is revenue being lost or delayed across our order pipeline,
# and which regions, customers, and product lines carry the most risk
# from cancelled, disputed, and on-hold orders?
#
# ## Dataset
# - Source: Kaggle — Automobile Sales Dataset
# - 2,747 order line items across 298 unique orders
# - 19 countries
# - Date range: 01/03/2020 to 31/05/2020
#
# ## Key Findings
# - Problem orders (Cancelled, Disputed, and On Hold) represent `4.5%` of total pipeline revenue — approximately `$446,000` across 118 orders
# - The **USA** accounts for the largest share of problem order revenue at roughly `$200,000`, nearly 2.5x the next highest countries (Spain and Sweden)
# - **Euro Shopping Channel** carries the highest problem order revenue at `$82,832` with 22 repeat problem orders across Cancelled and Disputed categories, suggesting a systemic relationship issue rather than isolated incidents
# - **Classic Cars** is the most affected product line at `30%` of problem order revenue (`$134,000`), with Medium sized deals driving the majority of problem orders across all product lines
# - Problem orders show a recurring seasonal pattern — **Q2 was the highest problem order quarter in both 2019 and 2020**, suggesting potential logistics or demand challenges specific to this time of year

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Auto Sales data.csv')

# %% [markdown]
# ## 1. Pipeline Overview — Revenue by Order Status
#
# Before isolating problem orders, we first look at how revenue is distributed
# across all order statuses to understand the full picture of the pipeline.

# %%
status_breakdown = df.groupby('STATUS').agg(
    order_count=('ORDERNUMBER', 'count'),
    total_sales=('SALES', 'sum')
).reset_index()

status_breakdown['percent_of_total'] = (
    status_breakdown['total_sales'] / status_breakdown['total_sales'].sum() * 100
).round(2)

status_breakdown = status_breakdown.sort_values('total_sales', ascending=False)

status_breakdown.rename(columns={
    'STATUS': 'Order Status',
    'order_count': 'Order Count',
    'total_sales': 'Total Sales ($)',
    'percent_of_total': 'Share of Total (%)'
}, inplace=True)

status_breakdown.style.format({
    'Total Sales ($)': '{:,.2f}',
    'Share of Total (%)': '{:.2f}'
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_a6c73_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Order Status</th>
#       <th class="col_heading level0 col1" >Order Count</th>
#       <th class="col_heading level0 col2" >Total Sales ($)</th>
#       <th class="col_heading level0 col3" >Share of Total (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6c73_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_a6c73_row0_col0" class="data row0 col0" >Shipped</td>
#       <td id="T_a6c73_row0_col1" class="data row0 col1" >2541</td>
#       <td id="T_a6c73_row0_col2" class="data row0 col2" >9,019,093.94</td>
#       <td id="T_a6c73_row0_col3" class="data row0 col3" >92.41</td>
#     </tr>
#     <tr>
#       <th id="T_a6c73_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_a6c73_row1_col0" class="data row1 col0" >Cancelled</td>
# ...

# %%
status_chart = df.groupby('STATUS').agg(
    order_count=('ORDERNUMBER', 'count'),
    total_sales=('SALES', 'sum')
).reset_index()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

colors = ['#2ecc71', '#e74c3c', '#e67e22', '#3498db', '#9b59b6', '#95a5a6']
wedges, texts, autotexts = ax1.pie(
    status_chart['total_sales'],
    labels=status_chart['STATUS'],
    autopct='%1.1f%%',
    colors=colors,
    pctdistance=0.85,
    wedgeprops=dict(width=0.5)
)
ax1.set_title('Pipeline Revenue by Order Status')

problem = status_chart[status_chart['STATUS'].isin(['Cancelled', 'Disputed', 'On Hold'])]
sns.barplot(data=problem, x='STATUS', y='total_sales', palette='Reds_d', ax=ax2, hue='STATUS')
ax2.set_title('Problem Order Revenue Breakdown')
ax2.set_xlabel('Order Status')
ax2.set_ylabel('Total Sales ($)')
ax2.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation
# The vast majority of revenue, roughly `$9,000,000`, comes from shipped orders, ensuring that the business is functioning properly. Looking deeper into problem orders (Cancelled, Disputed, and On Hold) these categories combined account for `4.5%`  of total revenue, roughly `$446,000`. Cancelled orders have the largest share at `2%`, followed by On Hold orders at `1.8%`, and Disputed at `0.7%`. Next, we'll group orders into broader categories to establish the headline problem order figure.

# %% [markdown]
# ## 2. Pipeline Revenue by Category
#
# Grouping orders into broader categories to establish a clear headline figure
# for problem order revenue across the pipeline.

# %%
category_map = {
    'Shipped': 'Completed Orders',
    'Resolved': 'Completed Orders',
    'Cancelled': 'Problem Orders',
    'Disputed': 'Problem Orders',
    'On Hold': 'Problem Orders',
    'In Process': 'Orders In Processing'
}

df['order_category'] = df['STATUS'].map(category_map)

category_breakdown = df.groupby('order_category').agg(
    order_count=('ORDERNUMBER', 'count'),
    total_sales=('SALES', 'sum')
).reset_index()

category_breakdown['percent_of_total'] = (
    category_breakdown['total_sales'] / category_breakdown['total_sales'].sum() * 100
).round(2)

category_breakdown = category_breakdown.sort_values('total_sales', ascending=False)

category_breakdown.rename(columns={
    'order_category': 'Order Category',
    'order_count': 'Order Count',
    'total_sales': 'Total Sales ($)',
    'percent_of_total': 'Share of Total (%)'
}, inplace=True)

category_breakdown.style.format({
    'Total Sales ($)': '{:,.2f}',
    'Share of Total (%)': '{:.2f}'
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_73eed_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Order Category</th>
#       <th class="col_heading level0 col1" >Order Count</th>
#       <th class="col_heading level0 col2" >Total Sales ($)</th>
#       <th class="col_heading level0 col3" >Share of Total (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73eed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_73eed_row0_col0" class="data row0 col0" >Completed Orders</td>
#       <td id="T_73eed_row0_col1" class="data row0 col1" >2588</td>
#       <td id="T_73eed_row0_col2" class="data row0 col2" >9,169,812.22</td>
#       <td id="T_73eed_row0_col3" class="data row0 col3" >93.95</td>
#     </tr>
#     <tr>
#       <th id="T_73eed_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_73eed_row1_col0" class="data row1 col0" >Problem Orders</td>
# ...

# %%
colors = ['#2ecc71', '#e74c3c', '#3498db']

plt.figure(figsize=(7, 7))
wedges, texts, autotexts = plt.pie(
    category_breakdown['Total Sales ($)'],
    labels=None,
    autopct='%1.1f%%',
    colors=colors,
    wedgeprops=dict(width=0.5),
    startangle=90,
    pctdistance=1.15
)
plt.legend(
    wedges,
    category_breakdown['Order Category'],
    title='Order Category',
    loc='lower center',
    bbox_to_anchor=(0.5, -0.08),
    ncol=3
)
plt.title('Pipeline Revenue by Order Category')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation
# Grouping all the orders into three distinct categories we have Completed Orders, Problem Orders, and Orders In Processing. The majority of orders are completed at `94%`. Problem orders are the next largest at `4.6%`, where orders that are currently being processed are just at `1.5%`. While a `94%` success rate is a respectable number, there is still room to improve and understand the reasoning behind problem orders. The following sections examine where these orders are concentrated geographically, by customer, and by product line.

# %% [markdown]
# ## 3. Geographic Distribution of Problem Orders
#
# Identifying which countries and regions have the highest concentration
# of problem orders to determine if there are geographic patterns driving
# cancellations, disputes, and holds.

# %%
problem_orders = df[df['STATUS'].isin(['Cancelled', 'Disputed', 'On Hold'])].copy()

country_breakdown = problem_orders.groupby('COUNTRY').agg(
    order_count=('ORDERNUMBER', 'count'),
    total_sales=('SALES', 'sum')
).reset_index()

country_breakdown['percent_of_total'] = (
    country_breakdown['total_sales'] / country_breakdown['total_sales'].sum() * 100
).round(2)

country_breakdown = country_breakdown.sort_values('total_sales', ascending=False)

country_breakdown.rename(columns={
    'COUNTRY': 'Country',
    'order_count': 'Order Count',
    'total_sales': 'Total Sales ($)',
    'percent_of_total': 'Share of Problem Orders (%)'
}, inplace=True)

country_breakdown.style.format({
    'Total Sales ($)': '{:,.2f}',
    'Share of Problem Orders (%)': '{:.2f}'
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_de233_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Country</th>
#       <th class="col_heading level0 col1" >Order Count</th>
#       <th class="col_heading level0 col2" >Total Sales ($)</th>
#       <th class="col_heading level0 col3" >Share of Problem Orders (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de233_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_de233_row0_col0" class="data row0 col0" >USA</td>
#       <td id="T_de233_row0_col1" class="data row0 col1" >52</td>
#       <td id="T_de233_row0_col2" class="data row0 col2" >198,076.64</td>
#       <td id="T_de233_row0_col3" class="data row0 col3" >44.44</td>
#     </tr>
#     <tr>
#       <th id="T_de233_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_de233_row1_col0" class="data row1 col0" >Spain</td>
# ...

# %%
plt.figure(figsize=(12, 5))
sns.barplot(
    data=country_breakdown,
    x='Country',
    y='Total Sales ($)',
    palette='Reds_d',
    hue='Country'
)
plt.title('Problem Order Revenue by Country')
plt.xlabel('Country')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation
# Looking into problem orders by geographic location it's clear there's a geographic concentration. The USA has the largest share of problem order revenue at around `$200,000`, almost `2.5x` the next highest countries. Spain and Sweden follow close to each other, at roughly `$82,000` and `$75,000`. The last three countries follow with the UK, Denmark, and Australia trailing significantly. The concentration of problem orders in the USA is notable, likely representing an overall larger market share. The next section will examine if specific customers in these regions are driving the pattern.

# %% [markdown]
# ## 4. Problem Orders by Customer
#
# Identifying which customers are repeatedly associated with problem orders
# to determine if specific relationships are driving a disproportionate share
# of cancellations, disputes, and holds.

# %%
customer_breakdown = problem_orders.groupby('CUSTOMERNAME').agg(
    order_count=('ORDERNUMBER', 'count'),
    total_sales=('SALES', 'sum')
).reset_index()

customer_breakdown['percent_of_total'] = (
    customer_breakdown['total_sales'] / customer_breakdown['total_sales'].sum() * 100
).round(2)

customer_breakdown = customer_breakdown.sort_values('total_sales', ascending=False).head(10)

customer_breakdown.rename(columns={
    'CUSTOMERNAME': 'Customer',
    'order_count': 'Order Count',
    'total_sales': 'Total Sales ($)',
    'percent_of_total': 'Share of Problem Orders (%)'
}, inplace=True)

customer_breakdown.style.format({
    'Total Sales ($)': '{:,.2f}',
    'Share of Problem Orders (%)': '{:.2f}'
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_b6bb3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Customer</th>
#       <th class="col_heading level0 col1" >Order Count</th>
#       <th class="col_heading level0 col2" >Total Sales ($)</th>
#       <th class="col_heading level0 col3" >Share of Problem Orders (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6bb3_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_b6bb3_row0_col0" class="data row0 col0" >Euro Shopping Channel</td>
#       <td id="T_b6bb3_row0_col1" class="data row0 col1" >22</td>
#       <td id="T_b6bb3_row0_col2" class="data row0 col2" >81,832.55</td>
#       <td id="T_b6bb3_row0_col3" class="data row0 col3" >18.36</td>
#     </tr>
#     <tr>
#       <th id="T_b6bb3_level0_row1" class="row_heading level0 row1" >7</th>
# ...

# %%
plt.figure(figsize=(12, 5))
sns.barplot(
    data=customer_breakdown,
    x='Customer',
    y='Total Sales ($)',
    palette='Reds_d',
    hue='Customer'
)
plt.title('Top 10 Customers by Problem Order Revenue')
plt.xlabel('Customer')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
repeat_offenders = problem_orders.groupby('CUSTOMERNAME').agg(
    total_orders=('ORDERNUMBER', 'count'),
    cancelled=('STATUS', lambda x: (x == 'Cancelled').sum()),
    disputed=('STATUS', lambda x: (x == 'Disputed').sum()),
    on_hold=('STATUS', lambda x: (x == 'On Hold').sum()),
    total_sales=('SALES', 'sum')
).reset_index()

repeat_offenders = repeat_offenders[repeat_offenders['total_orders'] > 1]
repeat_offenders = repeat_offenders.sort_values('total_orders', ascending=False).head(10)

repeat_offenders.rename(columns={
    'CUSTOMERNAME': 'Customer',
    'total_orders': 'Total Problem Orders',
    'cancelled': 'Cancelled',
    'disputed': 'Disputed',
    'on_hold': 'On Hold',
    'total_sales': 'Total Sales ($)'
}, inplace=True)

repeat_offenders.style.format({
    'Total Sales ($)': '{:,.2f}'
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_703b2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Customer</th>
#       <th class="col_heading level0 col1" >Total Problem Orders</th>
#       <th class="col_heading level0 col2" >Cancelled</th>
#       <th class="col_heading level0 col3" >Disputed</th>
#       <th class="col_heading level0 col4" >On Hold</th>
#       <th class="col_heading level0 col5" >Total Sales ($)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_703b2_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_703b2_row0_col0" class="data row0 col0" >Euro Shopping Channel</td>
#       <td id="T_703b2_row0_col1" class="data row0 col1" >22</td>
#       <td id="T_703b2_row0_col2" class="data row0 col2" >16</td>
#       <td id="T_703b2_row0_col3" class="data row0 col3" >6</td>
#       <td id="T_703b2_row0_col4" class="data row0 col4" >0</td>
# ...

# %% [markdown]
# ### Observation
# Euro Shopping Channel has the highest problem order revenue at `$82,832`, followed by The Sharp Gifts Warehouse and UK Collectables, Ltd. Looking at repeat offenders, Euro Shopping Channel stands out again with 22 problem orders across Cancelled and Disputed categories, ssuggesting this is a pattern rather than a single incident from this customer. Highest priority action should be directed towards customers with high revenue and multiple problem order types. Occasional cancellations are common, but with repeated issues across all problem order categories, this points towards a relationship or fulfillment problem.

# %% [markdown]
# ## 5. Product Line and Deal Size Analysis
#
# Examining which product lines and deal sizes are most affected by problem
# orders to identify if certain products or order sizes carry a higher risk
# of cancellation, dispute, or delay.

# %%
product_breakdown = problem_orders.groupby('PRODUCTLINE').agg(
    order_count=('ORDERNUMBER', 'count'),
    total_sales=('SALES', 'sum')
).reset_index()

product_breakdown['percent_of_total'] = (
    product_breakdown['total_sales'] / product_breakdown['total_sales'].sum() * 100
).round(2)

product_breakdown = product_breakdown.sort_values('total_sales', ascending=False)

product_breakdown.rename(columns={
    'PRODUCTLINE': 'Product Line',
    'order_count': 'Order Count',
    'total_sales': 'Total Sales ($)',
    'percent_of_total': 'Share of Problem Orders (%)'
}, inplace=True)

product_breakdown.style.format({
    'Total Sales ($)': '{:,.2f}',
    'Share of Problem Orders (%)': '{:.2f}'
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_fb972_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Product Line</th>
#       <th class="col_heading level0 col1" >Order Count</th>
#       <th class="col_heading level0 col2" >Total Sales ($)</th>
#       <th class="col_heading level0 col3" >Share of Problem Orders (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb972_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fb972_row0_col0" class="data row0 col0" >Classic Cars</td>
#       <td id="T_fb972_row0_col1" class="data row0 col1" >31</td>
#       <td id="T_fb972_row0_col2" class="data row0 col2" >134,295.33</td>
#       <td id="T_fb972_row0_col3" class="data row0 col3" >30.13</td>
#     </tr>
#     <tr>
#       <th id="T_fb972_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_fb972_row1_col0" class="data row1 col0" >Vintage Cars</td>
# ...

# %%
dealsize_breakdown = problem_orders.groupby(['PRODUCTLINE', 'DEALSIZE']).agg(
    order_count=('ORDERNUMBER', 'count')
).reset_index()

dealsize_pivot = dealsize_breakdown.pivot(
    index='PRODUCTLINE',
    columns='DEALSIZE',
    values='order_count'
).fillna(0).astype(int)

dealsize_pivot
dealsize_pivot['Total'] = dealsize_pivot.sum(axis=1)
dealsize_pivot.loc['Total'] = dealsize_pivot.sum(axis=0)
dealsize_pivot
# Out:
# DEALSIZE          Large  Medium  Small  Total
# PRODUCTLINE
# Classic Cars          5      15     11     31
# Motorcycles           2       4      1      7
# Planes                2       8     13     23
# Ships                 0      16     11     27
# Trains                0       2      0      2
# Trucks and Buses      0       3      1      4
# Vintage Cars          1      14      9     24
# Total                10      62     46    118

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Left — problem order revenue by product line
sns.barplot(
    data=product_breakdown,
    x='Product Line',
    y='Total Sales ($)',
    palette='Reds_d',
    hue='Product Line',
    legend=False,
    ax=ax1
)
ax1.set_title('Problem Order Revenue by Product Line')
ax1.set_xlabel('Product Line')
ax1.set_ylabel('Total Sales ($)')
ax1.tick_params(axis='x', rotation=45)

# Right — deal size heatmap, drop totals row/column if present
heatmap_data = dealsize_pivot.drop(index='Total', errors='ignore').drop(columns='Total', errors='ignore')

sns.heatmap(
    heatmap_data,
    annot=True,
    fmt='d',
    cmap='Reds',
    ax=ax2
)
ax2.set_title('Problem Orders by Product Line and Deal Size')
ax2.set_xlabel('Deal Size')
ax2.set_ylabel('Product Line')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation
# Classic Cars account for the largest share of problem order revenue at `30%`,
# roughly `$134,000` across 31 orders. This makes it the highest priority product
# line to investigate. Vintage Cars and Ships follow closely, both at around `19%`.
# The deal size breakdown shows that Medium sized deals have the most problem orders
# across almost all product lines, with Ships Medium deals containing the highest
# count at 16. Large deals have very few problem orders across all product lines,
# suggesting that bigger transactions are handled more thoroughly or go through a
# stricter approval process. The concentration in Classic Cars combined with Medium
# deal sizes points to a specific opportunity to investigate and improve existing
# processes that may be contributing to these problem orders.

# %% [markdown]
# ## 6. Time Pattern Analysis — Monthly and Quarterly Trends
#
# Examining whether problem orders cluster around specific months or quarters
# to identify any seasonal patterns driving cancellations, disputes, and holds.

# %%
problem_orders['ORDERDATE'] = pd.to_datetime(problem_orders['ORDERDATE'], dayfirst=True)

monthly_breakdown = problem_orders.groupby(
    problem_orders['ORDERDATE'].dt.to_period('M')
).agg(
    order_count=('ORDERNUMBER', 'count'),
    total_sales=('SALES', 'sum')
).reset_index()

monthly_breakdown['ORDERDATE'] = monthly_breakdown['ORDERDATE'].astype(str)
monthly_breakdown = monthly_breakdown.sort_values('ORDERDATE')

monthly_breakdown.rename(columns={
    'ORDERDATE': 'Month',
    'order_count': 'Problem Order Count',
    'total_sales': 'Total Sales ($)'
}, inplace=True)

monthly_breakdown.style.format({
    'Total Sales ($)': '{:,.2f}'
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_bea90_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Month</th>
#       <th class="col_heading level0 col1" >Problem Order Count</th>
#       <th class="col_heading level0 col2" >Total Sales ($)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bea90_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bea90_row0_col0" class="data row0 col0" >2018-10</td>
#       <td id="T_bea90_row0_col1" class="data row0 col1" >16</td>
#       <td id="T_bea90_row0_col2" class="data row0 col2" >48,710.92</td>
#     </tr>
#     <tr>
#       <th id="T_bea90_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bea90_row1_col0" class="data row1 col0" >2019-05</td>
#       <td id="T_bea90_row1_col1" class="data row1 col1" >14</td>
#       <td id="T_bea90_row1_col2" class="data row1 col2" >45,357.66</td>
#     </tr>
#     <tr>
# ...

# %%
quarterly_breakdown = problem_orders.groupby(
    problem_orders['ORDERDATE'].dt.to_period('Q')
).agg(
    order_count=('ORDERNUMBER', 'count'),
    total_sales=('SALES', 'sum')
).reset_index()

quarterly_breakdown['ORDERDATE'] = quarterly_breakdown['ORDERDATE'].astype(str)
quarterly_breakdown = quarterly_breakdown.sort_values('ORDERDATE')

quarterly_breakdown.rename(columns={
    'ORDERDATE': 'Quarter',
    'order_count': 'Problem Order Count',
    'total_sales': 'Total Sales ($)'
}, inplace=True)

quarterly_breakdown.style.format({
    'Total Sales ($)': '{:,.2f}'
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_9307d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Quarter</th>
#       <th class="col_heading level0 col1" >Problem Order Count</th>
#       <th class="col_heading level0 col2" >Total Sales ($)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9307d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9307d_row0_col0" class="data row0 col0" >2018Q4</td>
#       <td id="T_9307d_row0_col1" class="data row0 col1" >16</td>
#       <td id="T_9307d_row0_col2" class="data row0 col2" >48,710.92</td>
#     </tr>
#     <tr>
#       <th id="T_9307d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9307d_row1_col0" class="data row1 col0" >2019Q2</td>
#       <td id="T_9307d_row1_col1" class="data row1 col1" >44</td>
#       <td id="T_9307d_row1_col2" class="data row1 col2" >145,776.56</td>
#     </tr>
#     <tr>
# ...

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10))

# Top — monthly trend
ax1.bar(
    monthly_breakdown['Month'],
    monthly_breakdown['Total Sales ($)'],
    color='#e74c3c',
    alpha=0.7
)
ax1.set_title('Problem Order Revenue by Month')
ax1.set_xlabel('Month')
ax1.set_ylabel('Total Sales ($)')
ax1.tick_params(axis='x', rotation=45)

# Bottom — quarterly trend
ax2.bar(
    quarterly_breakdown['Quarter'],
    quarterly_breakdown['Total Sales ($)'],
    color='#c0392b',
    alpha=0.7
)
ax2.set_title('Problem Order Revenue by Quarter')
ax2.set_xlabel('Quarter')
ax2.set_ylabel('Total Sales ($)')
ax2.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation
# June 2016 saw the most problem orders with a count of 30, totaling roughly `$100,000`. April 2020 follows with 27 orders accounting for `$130,000`, and May 2020 with 25 orders at just under `$95,000`. Breaking it down by quarter, Q2 2020 stands out with 52 problem orders totaling `$225,000`. The next closest quarter was Q2 2019 with 44 orders totaling `$146,000`. Notably, both 2019 and 2020 saw elevated problem orders in Q2 — back to back years showing the same seasonal pattern. This suggests a recurring issue specific to this time of year. Further investigation may reveal underlying logistics or demand challenges during Q2 that are contributing to the uptick in problem orders.
